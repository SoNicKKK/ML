# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#filename = 'train.csv'
filename = 'test.csv'
df = pd.read_csv(filename)
df.head()
# Out:
#    Id                                           Sequence
# 0   1  1,0,0,2,24,552,21280,103760,70299264,579285324...
# 1   2  1,1,5,11,35,93,269,747,2115,5933,16717,47003,1...
# 2   4  0,1,101,2,15,102,73,3,40,16,47,103,51,74,116,4...
# 3   5  1,4,14,23,42,33,35,34,63,66,87,116,84,101,126,...
# 4   6  1,1,2,5,4,2,6,13,11,4,10,10,12,6,8,29,16,11,18...

# %%
df.columns = ['Id', 'ints']
a = df.ix[0].ints.split(',')[-1]

# %%
df['ints_list'] = df.ints.apply(lambda x: x.split(','))
df['ints_len'] = df.ints_list.apply(lambda x: len(x))
df['ints_data'] = df.ints_list.apply(lambda x: x[:-1])
df['res'] = df.ints_list.apply(lambda x: x[-1])
print('Longest:', df.ints_len.max())
df.head()
# Out:
# Longest: 347
#    Id                                               ints  \
# 0   1  1,0,0,2,24,552,21280,103760,70299264,579285324...
# 1   2  1,1,5,11,35,93,269,747,2115,5933,16717,47003,1...
# 2   4  0,1,101,2,15,102,73,3,40,16,47,103,51,74,116,4...
# 3   5  1,4,14,23,42,33,35,34,63,66,87,116,84,101,126,...
# 4   6  1,1,2,5,4,2,6,13,11,4,10,10,12,6,8,29,16,11,18...
#
#                                            ints_list  ints_len  \
# 0  [1, 0, 0, 2, 24, 552, 21280, 103760, 70299264,...        11
# 1  [1, 1, 5, 11, 35, 93, 269, 747, 2115, 5933, 16...        27
# 2  [0, 1, 101, 2, 15, 102, 73, 3, 40, 16, 47, 103...        51
# 3  [1, 4, 14, 23, 42, 33, 35, 34, 63, 66, 87, 116...        50
# 4  [1, 1, 2, 5, 4, 2, 6, 13, 11, 4, 10, 10, 12, 6...        70
#
#                                            ints_data           res
# 0  [1, 0, 0, 2, 24, 552, 21280, 103760, 70299264,...  587159944704
# 1  [1, 1, 5, 11, 35, 93, 269, 747, 2115, 5933, 16...  257733967693
# 2  [0, 1, 101, 2, 15, 102, 73, 3, 40, 16, 47, 103...           158
# 3  [1, 4, 14, 23, 42, 33, 35, 34, 63, 66, 87, 116...           406
# 4  [1, 1, 2, 5, 4, 2, 6, 13, 11, 4, 10, 10, 12, 6...            24

# %%
df.ints_len.max()
nrows, ncols = 4, 4
fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(20,20))
sns.set(style='whitegrid', context='notebook')
for i in range(nrows * ncols):
    row = df.ix[i]    
    x = np.arange(row.ints_len)
    y = row.ints_data
    res = row.res
    plt.subplot(nrows, ncols, i + 1)
    plt.scatter(x[:-1], y, c='g', label=str(i))
    plt.scatter(x[-1], res, c='r', s=30)
    plt.legend(loc='upper left')
sns.despine()

# %%
df1 = df.iloc[14]
df_train = pd.DataFrame()
df_train['x'] = np.arange(df1.ints_len)
df_train['x2'] = df_train.x ** 2
df_train['x3'] = df_train.x ** 3
df_train['x4'] = df_train.x ** 4
df_train['x5'] = df_train.x ** 5
df_train['sqrt'] = df_train.x ** .5
df_train['exp'] = np.exp(df_train.x).astype(float)
df_train['x0'] = 1
df_train['odd'] = df_train.x % 2
df_train['log'] = np.log(df_train.x).astype(float)
df_train['sin'] = np.sin(df_train.x)
df_train['cos'] = np.cos(df_train.x)
df_train['tan'] = np.tan(df_train.x)
df_train['res'] = df1.ints_list
df_train['prev'] = df_train.res.shift(1)
df_train = df_train[['x0', 'x', 'x2', 'x3', 'x4', 'x5', 'sqrt', 'odd', 'exp', 'log', 'sin', 'cos', 'tan', 'prev', 'res']]
df_train.tail()
# Out:
#     x0   x    x2     x3       x4         x5      sqrt  odd           exp  \
# 37   1  37  1369  50653  1874161   69343957  6.082763    1  1.171914e+16
# 38   1  38  1444  54872  2085136   79235168  6.164414    0  3.185593e+16
# 39   1  39  1521  59319  2313441   90224199  6.244998    1  8.659340e+16
# 40   1  40  1600  64000  2560000  102400000  6.324555    0  2.353853e+17
# 41   1  41  1681  68921  2825761  115856201  6.403124    1  6.398435e+17
#
#          log       sin       cos       tan  prev   res
# 37  3.610918 -0.643538  0.765414 -0.840771   966   997
# 38  3.637586  0.296369  0.955074  0.310310   997  1029
# 39  3.663562  0.963795  0.266643  3.614554  1029  1060
# 40  3.688879  0.745113 -0.666938 -1.117215  1060  1092
# 41  3.713572 -0.158623 -0.987339  0.160657  1092  1123

# %%
cols = [col for col in df_train.columns if col != 'res']
print(cols)
# Out:
# ['x0', 'x', 'x2', 'x3', 'x4', 'x5', 'sqrt', 'odd', 'exp', 'log', 'sin', 'cos', 'tan', 'prev']

# %%
df_train.replace(np.inf, np.nan, inplace=True)
df_train.replace(-np.inf, np.nan, inplace=True)
df_train.dropna(inplace=True)
df_train = df_train.reset_index()

# %%
from sklearn import linear_model
lr = linear_model.LinearRegression()
X_train = df_train[cols]
y_train = df_train.res
X_test = df_train[cols]
lr.fit(X_train, y_train)
pred = lr.predict(X_test)
df_train['predict'] = pred

# %%
from sklearn import cross_validation
import warnings
#kf = cross_validation.KFold(len(X_train.index), n_folds=5, shuffle=True)
alphas = [10 ** x for x in range(-5, 5)]
with warnings.catch_warnings():
    warnings.filterwarnings('error')
    try:
        lr_rigdeCV = linear_model.RidgeCV(alphas=alphas)
        lr_rigdeCV.fit(X_train, y_train)
        best_alpha = lr_rigdeCV.alpha_        
    except: best_alpha = 0.1
    
print('Alpha =', best_alpha)    
lr_ridge = linear_model.Ridge(alpha=best_alpha)
lr_ridge.fit(X_train, y_train)
pred_ridge = lr_ridge.predict(X_test)
df_train['predict_ridge'] = pred_ridge

scores = cross_validation.cross_val_score(lr_ridge, X_train, y_train, cv=10)
print('Cross validation score =', np.mean(scores))
# Out:
# Alpha = 0.001
# Cross validation score = 0.993642941147

# %%
import seaborn as sns
sns.set(style='whitegrid', context='talk')
plt.scatter(df_train[:-1].x, df_train[:-1].res, s=20, c='g', label='Train set')

for j in range(5):    
    plt.scatter(df_train[-1:].x, df_train[-1:].res, s=50+5**j, c='green', alpha=0.52-0.12*j, label='_')
    plt.scatter(df_train[-1:].x, df_train[-1:].predict,  s=50+5**j, c='red', alpha=0.52-0.12*j, label='_')
    plt.scatter(df_train[-1:].x, df_train[-1:].predict_ridge,  s=50+5**j, c='darkblue', alpha=0.52-0.12*j, label='_')
    
plt.plot(df_train.x, df_train.predict, '-', c='r', lw=0.8, ms=5, label='LinReg')
plt.plot(df_train.x, df_train.predict_ridge, '-', c='darkblue', lw=0.8, ms=5, label='LinReg Ridge')
plt.legend(loc='upper left', frameon=True)
#sns.despine()
res = df_train[-1:].res
lr_p = int(np.round(float(df_train[-1:].predict.values[0])))
lrr_p = int(np.round(float(df_train[-1:].predict_ridge.values[0])))
plt.title('Real value = %s,\nLinReg pred = %s,\nLinReg Ridge pred = %s' 
          % (str(df_train[-1:].res.values[0]), str(lr_p), str(lrr_p)))

# %%
# Check recursion

def get_matrix(seq, order):
    A = []
    for i in range(order + 1):
        s = [1] + seq[i:i+order]
        A = s if i == 0 else np.vstack([A, s]) 
    b = seq[order:2*order+1]
    return A, b

def check_recursion(seq):
    p = len(seq) - 1
    n = int(p/2 -1)
    try:
        A, b = get_matrix(seq, n)
        if  np.linalg.matrix_rank(A) - 1 < n:
            n = np.linalg.matrix_rank(A) - 1
            A, b = get_matrix(seq, n)
        w = np.linalg.solve(A, b)    
        # check
        feat_check_A = [1] + seq[n+1:2*n+1]
        feat_check_b = seq[2*n+1]
        if np.dot(feat_check_A, w) == feat_check_b:        
            feat_pred_A = [1] + seq[p-n+1:]
            predict = np.dot(feat_pred_A, w)
            return int(predict)
        else: return None        
    except:
        return None

# %%
from sklearn import linear_model 
from sklearn import cross_validation
import time
preds = []
longest = df.ints_len.max()
#cnt = 200
cnt = len(df.index)

df_train = pd.DataFrame()
df_train['x'] = np.arange(longest)
df_train['x0'] = 1
df_train['x2'] = df_train.x ** 2
df_train['x3'] = df_train.x ** 3
df_train['x4'] = df_train.x ** 4
df_train['sqrt'] = df_train.x ** .5
df_train['exp'] = np.exp(df_train.x)
df_train['odd'] = df_train.x % 2
df_train['log'] = np.log(df_train.x)
df_train['sin'] = np.sin(df_train.x)
df_train['cos'] = np.cos(df_train.x)

alphas = [10 ** x for x in range(-4, 4)]
#nrows, ncols = 4, 4
#cnt = nrows * ncols
#fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(18,18))
#sns.set(style='whitegrid', context='notebook')

st = time.time()
df['recursion'] = df.ints_list.apply(lambda x: check_recursion(list(map(int, x))))
print('Recursions checked. Time elapsed: %.2f min' % ((time.time() - st) / 60))

st = time.time()
for i in range(cnt):
    if (i % 1000 == 0) & (i != 0):
        print('Sequences: %d of %d, time elapsed: %.2f min, total estimated time: %.2f min' 
              % (i, cnt, (time.time() - st) / 60, (time.time() - st) * cnt / (60 * i)))        
    #print(i)
    df1 = df.ix[i]
    df_curr = df_train[:df1.ints_len].copy(deep=True)    
    df_curr['res'] = df1.ints_list
    df_curr['prev'] = df_curr.res.shift(1)    
    df_curr = df_curr[['x0', 'x', 'x2', 'x3', 'x4', 'sqrt', 'odd', 'exp', 'log', 'sin', 'cos', 'prev', 'res']]

    cols = [col for col in df_curr.columns if col != 'res']    
    df_curr = df_curr[1:].reset_index()
    
    if not df_curr.empty:    
        X_train = df_curr[cols]
        y_train = df_curr.res
        X_test = df_curr[cols]
        
        lr = linear_model.LinearRegression()        
        lr.fit(X_train, y_train)        
        pred = lr.predict(X_test)
        df_curr['predict'] = pred        
        #preds.append(df_curr[-1:].predict)
        
        with warnings.catch_warnings():
            warnings.simplefilter("error")            
            try:
                lr_rigdeCV = linear_model.RidgeCV(alphas=alphas)
                lr_rigdeCV.fit(X_train, y_train)
                best_alpha = lr_rigdeCV.alpha_
            except: best_alpha = 0.1
            
            try:
                lr_ridge = linear_model.Ridge(alpha=best_alpha)
                lr_ridge.fit(X_train, y_train)
                pred_ridge = lr_ridge.predict(X_test)
            except: pred_ridge = pred

        df_curr['predict_ridge'] = pred_ridge
        preds.append(df_curr[-1:].predict_ridge.values[0])        
        
    else:
        preds.append(df1.ints_list[-1])
    
    #plt.subplot(nrows, ncols, i + 1)
    #plt.scatter(df_curr[:-1].x, df_curr[:-1].res, s=20, c='g', label='Train set ' + str(i))

    #for j in range(5):    
    #    plt.scatter(df_curr[-1:].x, df_curr[-1:].res, s=50+5**j, c='green', alpha=0.52-0.12*j, label='_')
    #    plt.scatter(df_curr[-1:].x, df_curr[-1:].predict,  s=50+5**j, c='red', alpha=0.52-0.12*j, label='_')
    #    plt.scatter(df_curr[-1:].x, df_curr[-1:].predict_ridge,  s=50+5**j, c='darkblue', alpha=0.52-0.12*j, label='_')

    #plt.plot(df_curr.x, df_curr.predict, '-', c='r', lw=0.8, ms=5, label='LinReg')
    #plt.plot(df_curr.x, df_curr.predict_ridge, '-', c='darkblue', lw=0.8, ms=5, label='LinReg Ridge')
    #plt.legend(loc='upper left', frameon=True)    
    
print(len(df.index), len(preds))
print('Time %.2f sec' % (time.time() - st))
print('Estimated time for full test data: %.2f min' % ((time.time() - st) * int(len(df.index)) / (60 * int(len(preds)))))
df['preds'] = preds
# Out:
# Recursions checked. Time elapsed: 1.27 min
# Sequences: 1000 of 113845, time elapsed: 0.24 min, total estimated time: 27.25 min
# Sequences: 2000 of 113845, time elapsed: 0.53 min, total estimated time: 29.94 min
# Sequences: 3000 of 113845, time elapsed: 0.85 min, total estimated time: 32.39 min
# Sequences: 4000 of 113845, time elapsed: 1.08 min, total estimated time: 30.80 min
# Sequences: 5000 of 113845, time elapsed: 1.32 min, total estimated time: 30.02 min
# Sequences: 6000 of 113845, time elapsed: 1.56 min, total estimated time: 29.66 min
# Sequences: 7000 of 113845, time elapsed: 1.77 min, total estimated time: 28.71 min
# Sequences: 8000 of 113845, time elapsed: 2.03 min, total estimated time: 28.95 min
# Sequences: 9000 of 113845, time elapsed: 2.25 min, total estimated time: 28.48 min
# Sequences: 10000 of 113845, time elapsed: 2.47 min, total estimated time: 28.07 min
# Sequences: 11000 of 113845, time elapsed: 2.74 min, total estimated time: 28.33 min
# Sequences: 12000 of 113845, time elapsed: 2.95 min, total estimated time: 28.03 min
# Sequences: 13000 of 113845, time elapsed: 3.18 min, total estimated time: 27.87 min
# Sequences: 14000 of 113845, time elapsed: 3.43 min, total estimated time: 27.92 min
# Sequences: 15000 of 113845, time elapsed: 3.63 min, total estimated time: 27.53 min
# Sequences: 16000 of 113845, time elapsed: 3.82 min, total estimated time: 27.15 min
# Sequences: 17000 of 113845, time elapsed: 4.04 min, total estimated time: 27.06 min
# Sequences: 18000 of 113845, time elapsed: 4.23 min, total estimated time: 26.73 min
# Sequences: 19000 of 113845, time elapsed: 4.45 min, total estimated time: 26.64 min
# Sequences: 20000 of 113845, time elapsed: 4.62 min, total estimated time: 26.28 min
# Sequences: 21000 of 113845, time elapsed: 4.80 min, total estimated time: 26.01 min
# Sequences: 22000 of 113845, time elapsed: 4.98 min, total estimated time: 25.75 min
# Sequences: 23000 of 113845, time elapsed: 5.17 min, total estimated time: 25.59 min
# Sequences: 24000 of 113845, time elapsed: 5.34 min, total estimated time: 25.33 min
# Sequences: 25000 of 113845, time elapsed: 5.51 min, total estimated time: 25.09 min
# Sequences: 26000 of 113845, time elapsed: 5.71 min, total estimated time: 25.02 min
# Sequences: 27000 of 113845, time elapsed: 5.92 min, total estimated time: 24.97 min
# Sequences: 28000 of 113845, time elapsed: 6.12 min, total estimated time: 24.88 min
# Sequences: 29000 of 113845, time elapsed: 6.32 min, total estimated time: 24.83 min
# Sequences: 30000 of 113845, time elapsed: 6.55 min, total estimated time: 24.85 min
# Sequences: 31000 of 113845, time elapsed: 6.78 min, total estimated time: 24.91 min
# Sequences: 32000 of 113845, time elapsed: 7.01 min, total estimated time: 24.95 min
# Sequences: 33000 of 113845, time elapsed: 7.24 min, total estimated time: 24.97 min
# Sequences: 34000 of 113845, time elapsed: 7.45 min, total estimated time: 24.96 min
# Sequences: 35000 of 113845, time elapsed: 7.64 min, total estimated time: 24.84 min
# Sequences: 36000 of 113845, time elapsed: 7.90 min, total estimated time: 24.99 min
# Sequences: 37000 of 113845, time elapsed: 8.18 min, total estimated time: 25.18 min
# Sequences: 38000 of 113845, time elapsed: 8.38 min, total estimated time: 25.12 min
# Sequences: 39000 of 113845, time elapsed: 8.59 min, total estimated time: 25.08 min
# Sequences: 40000 of 113845, time elapsed: 8.83 min, total estimated time: 25.12 min
# Sequences: 41000 of 113845, time elapsed: 9.00 min, total estimated time: 24.98 min
# Sequences: 42000 of 113845, time elapsed: 9.17 min, total estimated time: 24.85 min
# Sequences: 43000 of 113845, time elapsed: 9.35 min, total estimated time: 24.76 min
# Sequences: 44000 of 113845, time elapsed: 9.52 min, total estimated time: 24.64 min
# Sequences: 45000 of 113845, time elapsed: 9.69 min, total estimated time: 24.52 min
# Sequences: 46000 of 113845, time elapsed: 9.86 min, total estimated time: 24.41 min
# Sequences: 47000 of 113845, time elapsed: 10.03 min, total estimated time: 24.31 min
# Sequences: 48000 of 113845, time elapsed: 10.20 min, total estimated time: 24.20 min
# Sequences: 49000 of 113845, time elapsed: 10.38 min, total estimated time: 24.11 min
# Sequences: 50000 of 113845, time elapsed: 10.55 min, total estimated time: 24.02 min
# Sequences: 51000 of 113845, time elapsed: 10.72 min, total estimated time: 23.92 min
# Sequences: 52000 of 113845, time elapsed: 10.89 min, total estimated time: 23.84 min
# Sequences: 53000 of 113845, time elapsed: 11.06 min, total estimated time: 23.76 min
# Sequences: 54000 of 113845, time elapsed: 11.27 min, total estimated time: 23.76 min
# Sequences: 55000 of 113845, time elapsed: 11.51 min, total estimated time: 23.82 min
# Sequences: 56000 of 113845, time elapsed: 11.71 min, total estimated time: 23.81 min
# Sequences: 57000 of 113845, time elapsed: 11.88 min, total estimated time: 23.74 min
# Sequences: 58000 of 113845, time elapsed: 12.06 min, total estimated time: 23.66 min
# Sequences: 59000 of 113845, time elapsed: 12.24 min, total estimated time: 23.62 min
# Sequences: 60000 of 113845, time elapsed: 12.41 min, total estimated time: 23.56 min
# Sequences: 61000 of 113845, time elapsed: 12.59 min, total estimated time: 23.49 min
# Sequences: 62000 of 113845, time elapsed: 12.76 min, total estimated time: 23.42 min
# Sequences: 63000 of 113845, time elapsed: 12.93 min, total estimated time: 23.36 min
# Sequences: 64000 of 113845, time elapsed: 13.10 min, total estimated time: 23.30 min
# Sequences: 65000 of 113845, time elapsed: 13.27 min, total estimated time: 23.24 min
# Sequences: 66000 of 113845, time elapsed: 13.44 min, total estimated time: 23.19 min
# Sequences: 67000 of 113845, time elapsed: 13.61 min, total estimated time: 23.13 min
# Sequences: 68000 of 113845, time elapsed: 13.80 min, total estimated time: 23.11 min
# Sequences: 69000 of 113845, time elapsed: 13.97 min, total estimated time: 23.05 min
# Sequences: 70000 of 113845, time elapsed: 14.14 min, total estimated time: 23.00 min
# Sequences: 71000 of 113845, time elapsed: 14.32 min, total estimated time: 22.95 min
# Sequences: 72000 of 113845, time elapsed: 14.48 min, total estimated time: 22.90 min
# Sequences: 73000 of 113845, time elapsed: 14.66 min, total estimated time: 22.86 min
# Sequences: 74000 of 113845, time elapsed: 14.83 min, total estimated time: 22.82 min
# Sequences: 75000 of 113845, time elapsed: 15.02 min, total estimated time: 22.80 min
# Sequences: 76000 of 113845, time elapsed: 15.20 min, total estimated time: 22.77 min
# Sequences: 77000 of 113845, time elapsed: 15.41 min, total estimated time: 22.79 min
# Sequences: 78000 of 113845, time elapsed: 15.61 min, total estimated time: 22.78 min
# Sequences: 79000 of 113845, time elapsed: 15.78 min, total estimated time: 22.75 min
# Sequences: 80000 of 113845, time elapsed: 15.96 min, total estimated time: 22.71 min
# Sequences: 81000 of 113845, time elapsed: 16.13 min, total estimated time: 22.68 min
# Sequences: 82000 of 113845, time elapsed: 16.31 min, total estimated time: 22.64 min
# Sequences: 83000 of 113845, time elapsed: 16.48 min, total estimated time: 22.61 min
# Sequences: 84000 of 113845, time elapsed: 16.66 min, total estimated time: 22.58 min
# Sequences: 85000 of 113845, time elapsed: 16.83 min, total estimated time: 22.55 min
# Sequences: 86000 of 113845, time elapsed: 17.01 min, total estimated time: 22.51 min
# Sequences: 87000 of 113845, time elapsed: 17.18 min, total estimated time: 22.48 min
# Sequences: 88000 of 113845, time elapsed: 17.35 min, total estimated time: 22.44 min
# Sequences: 89000 of 113845, time elapsed: 17.52 min, total estimated time: 22.41 min
# Sequences: 90000 of 113845, time elapsed: 17.69 min, total estimated time: 22.38 min
# Sequences: 91000 of 113845, time elapsed: 17.86 min, total estimated time: 22.35 min
# Sequences: 92000 of 113845, time elapsed: 18.06 min, total estimated time: 22.35 min
# Sequences: 93000 of 113845, time elapsed: 18.29 min, total estimated time: 22.38 min
# Sequences: 94000 of 113845, time elapsed: 18.46 min, total estimated time: 22.35 min
# Sequences: 95000 of 113845, time elapsed: 18.63 min, total estimated time: 22.32 min
# Sequences: 96000 of 113845, time elapsed: 18.80 min, total estimated time: 22.29 min
# Sequences: 97000 of 113845, time elapsed: 18.97 min, total estimated time: 22.27 min
# Sequences: 98000 of 113845, time elapsed: 19.14 min, total estimated time: 22.24 min
# Sequences: 99000 of 113845, time elapsed: 19.31 min, total estimated time: 22.21 min
# Sequences: 100000 of 113845, time elapsed: 19.49 min, total estimated time: 22.18 min
# Sequences: 101000 of 113845, time elapsed: 19.66 min, total estimated time: 22.16 min
# Sequences: 102000 of 113845, time elapsed: 19.83 min, total estimated time: 22.13 min
# Sequences: 103000 of 113845, time elapsed: 20.00 min, total estimated time: 22.11 min
# Sequences: 104000 of 113845, time elapsed: 20.17 min, total estimated time: 22.08 min
# Sequences: 105000 of 113845, time elapsed: 20.34 min, total estimated time: 22.06 min
# Sequences: 106000 of 113845, time elapsed: 20.51 min, total estimated time: 22.03 min
# Sequences: 107000 of 113845, time elapsed: 20.69 min, total estimated time: 22.01 min
# Sequences: 108000 of 113845, time elapsed: 20.86 min, total estimated time: 21.99 min
# Sequences: 109000 of 113845, time elapsed: 21.04 min, total estimated time: 21.98 min
# Sequences: 110000 of 113845, time elapsed: 21.22 min, total estimated time: 21.96 min
# Sequences: 111000 of 113845, time elapsed: 21.40 min, total estimated time: 21.95 min
# Sequences: 112000 of 113845, time elapsed: 21.59 min, total estimated time: 21.95 min
# Sequences: 113000 of 113845, time elapsed: 21.77 min, total estimated time: 21.93 min
# 113845 113845
# Time 1314.73 sec
# Estimated time for full test data: 21.91 min

# %%
df['Last'] = df.recursion
df.Last.fillna(df.preds, inplace=True)
df['Last'] = df['Last'].apply(lambda x: int(np.round(float(x))))
print(df[['Id', 'Last']].head(10))
df[['Id', 'Last']].to_csv('submission.csv', sep=',', index=False)
# Out:
#    Id                        Last
# 0   1                587020672973
# 1   2                725161963867
# 2   4                         158
# 3   5                         402
# 4   6                          23
# 5   9                        1430
# 6  10            1589719078594515
# 7  12      7564280948067895607296
# 8  14  10576607846652308357120000
# 9  17      2795903765047156408320
