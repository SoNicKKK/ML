# %%
import numpy as np
import pandas as pd
import time
import warnings
from sklearn import linear_model 
from sklearn import cross_validation

# %%
filename = 'test.csv'
df = pd.read_csv(filename)
df.columns = ['Id', 'ints']
df['ints_list'] = df.ints.apply(lambda x: x.split(','))
df['ints_len'] = df.ints_list.apply(lambda x: len(x))
df['last'] = df.ints_list.apply(lambda x: int(x[-1]))
df.drop('ints', axis=1, inplace=True)
print('Longest:', df.ints_len.max())
longest = df.ints_len.max() + 1
df.head()
# Out:
# Longest: 347
#    Id                                          ints_list  ints_len  \
# 0   1  [1, 0, 0, 2, 24, 552, 21280, 103760, 70299264,...        11
# 1   2  [1, 1, 5, 11, 35, 93, 269, 747, 2115, 5933, 16...        27
# 2   4  [0, 1, 101, 2, 15, 102, 73, 3, 40, 16, 47, 103...        51
# 3   5  [1, 4, 14, 23, 42, 33, 35, 34, 63, 66, 87, 116...        50
# 4   6  [1, 1, 2, 5, 4, 2, 6, 13, 11, 4, 10, 10, 12, 6...        70
#
#            last
# 0  587159944704
# 1  257733967693
# 2           158
# 3           406
# 4            24

# %%
df_train = pd.DataFrame()
df_train['x'] = np.arange(longest)
df_train['x0'] = 1
df_train['x2'] = df_train.x ** 2
df_train['x3'] = df_train.x ** 3
df_train['x4'] = df_train.x ** 4
df_train['sqrt'] = df_train.x ** .5
df_train['exp'] = np.exp(df_train.x)
df_train['odd'] = df_train.x % 2
df_train['log'] = np.log(df_train.x)
df_train['sin'] = np.sin(df_train.x)
df_train['cos'] = np.cos(df_train.x)
df_train.tail()
# Out:
#        x  x0      x2        x3           x4       sqrt            exp  odd  \
# 343  343   1  117649  40353607  13841287201  18.520259  9.183480e+148    1
# 344  344   1  118336  40707584  14003408896  18.547237  2.496329e+149    0
# 345  345   1  119025  41063625  14166950625  18.574176  6.785725e+149    1
# 346  346   1  119716  41421736  14331920656  18.601075  1.844551e+150    0
# 347  347   1  120409  41781923  14498327281  18.627936  5.014010e+150    1
#
#           log       sin       cos
# 343  5.837730 -0.536598 -0.843838
# 344  5.840642 -0.999990 -0.004396
# 345  5.843544 -0.543996  0.839088
# 346  5.846439  0.412146  0.911118
# 347  5.849325  0.989363  0.145470

# %%
cols = [col for col in df_train.columns if col != 'res']
cols
# Out:
# ['x', 'x0', 'x2', 'x3', 'x4', 'sqrt', 'exp', 'odd', 'log', 'sin', 'cos']

# %%
# Check recursion

def get_matrix(seq, order):
    A = []
    for i in range(order + 1):
        s = [1] + seq[i:i+order]
        A = s if i == 0 else np.vstack([A, s]) 
    b = seq[order:2*order+1]
    return A, b

def check_recursion(seq):
    p = len(seq) - 1
    n = int(p/2 -1)
    try:
        A, b = get_matrix(seq, n)
        if  np.linalg.matrix_rank(A) - 1 < n:
            n = np.linalg.matrix_rank(A) - 1
            A, b = get_matrix(seq, n)
        w = np.linalg.solve(A, b)    
        # check
        feat_check_A = [1] + seq[n+1:2*n+1]
        feat_check_b = seq[2*n+1]
        if np.dot(feat_check_A, w) == feat_check_b:        
            feat_pred_A = [1] + seq[p-n+1:]
            predict = np.dot(feat_pred_A, w)
            return int(predict)
        else: return np.nan        
    except:
        return np.nan

# %%
# check some recursions
import time
st = time.time()
def get_diffs(x):
    return [x[i+1] - x[i] for i in range(len(x) - 1)] if len(x) > 1 else x    

df['ints_list'] = df.ints_list.apply(lambda x: list(map(int, x)))
df['diffs'] = df.ints_list.apply(get_diffs)
df['plus1'] = df.ints_list.apply(lambda x: [i+1 for i in x])
df['minus1'] = df.ints_list.apply(lambda x: [i-1 for i in x])
print('time: %.2f min' % ((time.time() - st) / 60))
# Out:
# time: 0.10 min

# %%
st = time.time()
#print(df.ix[0])
df['recursion'] = df['Id'].map(pd.read_csv('test_recursion_result.csv', encoding='utf-8-sig').set_index('Id').recursion)
df['rec_diffs'] = df.apply(lambda row: check_recursion(row.diffs) + row['last'], axis=1)
df['rec_plus1'] = df.plus1.apply(lambda x: check_recursion(x) - 1)
df['rec_minus1'] = df.minus1.apply(lambda x: check_recursion(x) + 1)
print('time: %.2f min' % ((time.time() - st) / 60))
# Out:
# time: 4.27 min

# %%
print(df[df.recursion.notnull()].Id.count() / len(df.index))
df.recursion.fillna(df.rec_diffs, inplace=True)
df.recursion.fillna(df.rec_plus1, inplace=True)
df.recursion.fillna(df.rec_minus1, inplace=True)
print(df[df.recursion.notnull()].Id.count() / len(df.index))
df[['Id', 'recursion']].to_csv('test_full_recursion_result.csv', encoding='utf-8-sig')
# Out:
# 0.0924678290658
# 0.126241820018

# %%
st = time.time()

# check recursion and write to file

#df['recursion'] = df.ints_list.apply(lambda x: check_recursion(list(map(int, x))))
#print('Recursions checked. Time elapsed: %.2f min' % ((time.time() - st) / 60))
#print('Recursion detected for %.4f sequences' % (df[df.recursion.isnull() == False].Id.count() / df.Id.count()))
#df[['Id', 'recursion']].to_csv('test_recursion_result.csv', index=False)
#pd.read_csv('test_recursion_result.csv', encoding='utf-8-sig')

# get recursion result from file
df['recursion'] = df['Id'].map(pd.read_csv('test_full_recursion_result.csv', encoding='utf-8-sig').set_index('Id').recursion)
df.head()
# Out:
#    Id                                          ints_list  ints_len  \
# 0   1  [1, 0, 0, 2, 24, 552, 21280, 103760, 70299264,...        11
# 1   2  [1, 1, 5, 11, 35, 93, 269, 747, 2115, 5933, 16...        27
# 2   4  [0, 1, 101, 2, 15, 102, 73, 3, 40, 16, 47, 103...        51
# 3   5  [1, 4, 14, 23, 42, 33, 35, 34, 63, 66, 87, 116...        50
# 4   6  [1, 1, 2, 5, 4, 2, 6, 13, 11, 4, 10, 10, 12, 6...        70
#
#            last                                              diffs  \
# 0  587159944704  [-1, 0, 2, 22, 528, 20728, 82480, 70195504, 57...
# 1  257733967693  [0, 4, 6, 24, 58, 176, 478, 1368, 3818, 10784,...
# 2           158  [1, 100, -99, 13, 87, -29, -70, 37, -24, 31, 5...
# 3           406  [3, 10, 9, 19, -9, 2, -1, 29, 3, 21, 29, -32, ...
# 4            24  [0, 1, 3, -1, -2, 4, 7, -2, -7, 6, 0, 2, -6, 2...
#
#                                                plus1  \
# 0  [2, 1, 1, 3, 25, 553, 21281, 103761, 70299265,...
# 1  [2, 2, 6, 12, 36, 94, 270, 748, 2116, 5934, 16...
# 2  [1, 2, 102, 3, 16, 103, 74, 4, 41, 17, 48, 104...
# 3  [2, 5, 15, 24, 43, 34, 36, 35, 64, 67, 88, 117...
# 4  [2, 2, 3, 6, 5, 3, 7, 14, 12, 5, 11, 11, 13, 7...
#
#                                               minus1     recursion  \
# 0  [0, -1, -1, 1, 23, 551, 21279, 103759, 7029926...           NaN
# 1  [0, 0, 4, 10, 34, 92, 268, 746, 2114, 5932, 16...  7.251620e+11
# 2  [-1, 0, 100, 1, 14, 101, 72, 2, 39, 15, 46, 10...           NaN
# 3  [0, 3, 13, 22, 41, 32, 34, 33, 62, 65, 86, 115...           NaN
# 4  [0, 0, 1, 4, 3, 1, 5, 12, 10, 3, 9, 9, 11, 5, ...           NaN
#
#       rec_diffs     rec_plus1 rec_minus1
# 0           NaN           NaN        NaN
# 1  725161963867  725161963867        NaN
# 2           NaN           NaN        NaN
# 3           NaN           NaN        NaN
# 4           NaN           NaN        NaN

# %%
preds = []
longest = df.ints_len.max() + 1
alphas = [10 ** x for x in range(-4, 4)]

#cnt = 5
cnt = len(df.index)

#nrows, ncols = 4, 4
#cnt = nrows * ncols
#fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(18,18))
#sns.set(style='whitegrid', context='notebook')

st = time.time()
for i in range(cnt):
    if (i % 2000 == 0) & (i != 0):
        print('Sequences: %d of %d (%.2f%% done), time elapsed: %.2f min, estimated time: %.2f min' 
              % (i, cnt, 100 * i / cnt, (time.time() - st) / 60, (time.time() - st) * cnt / (60 * i)))        
    #print(i)
    df1 = df.ix[i]
    if np.isnan(df1.recursion): # do linear regression only if no recursion detected
        df_curr = df_train[:df1.ints_len + 1].copy(deep=True)       
        df_curr['res'] = df1.ints_list + [np.nan]
        df_curr['prev'] = df_curr.res.shift(1)
        ints_ser = pd.Series(list(map(int, df1.ints_list)))
        default_value = df1.ints_list[-1]
        #def_func = np.mean(ints_ser)
        try:
            freqs = ints_ser[ints_ser < np.iinfo(np.int64).max].value_counts() 
            if len(freqs.index) > 2:
                freq, next_freq = freqs.iloc[0], freqs.iloc[1]
                default_value = freqs.idxmax() if freq / next_freq >= 2 else default_value            
        except OverflowError: default_value

        cols = [col for col in df_curr.columns if col != 'res']    
        df_curr = df_curr[1:].reset_index()

        if len(df_curr.index) > 1:
            X_train = df_curr[:-1][cols]
            y_train = df_curr[:-1].res          
            X_test = df_curr[-1:][cols]

            #lr = linear_model.LinearRegression()
            #lr.fit(X_train, y_train)
            #predict = lr.predict(X_test)[0]  
            #print('predict after LR:', predict)  

            with warnings.catch_warnings():
                warnings.simplefilter("error")            
                try:
                    lr_rigdeCV = linear_model.RidgeCV(alphas=alphas)
                    lr_rigdeCV.fit(X_train, y_train)
                    best_alpha = lr_rigdeCV.alpha_
                except: best_alpha = 0.1

                try:
                    lr_ridge = linear_model.Ridge(alpha=best_alpha)
                    lr_ridge.fit(X_train, y_train)
                    predict = lr_ridge.predict(X_test)[0]
                except: predict = default_value
                #print('predict after ridge LR:', predict)

                if len(X_train.index) > 5:
                    try:
                        kf = cross_validation.KFold(len(X_train.index), n_folds=5, shuffle=True)
                        scores = cross_validation.cross_val_score(lr_ridge, X_train, y_train, cv=kf)
                        predict = default_value if np.mean(scores) < 0.999 else default_value
                    except: predict = default_value
                else: predict = default_value
                #print('predict after cross validation:', predict)

            preds.append(predict)
        else:
            preds.append(default_value)
    else:
        preds.append(df1.recursion)
    
    #plt.subplot(nrows, ncols, i + 1)
    #plt.scatter(df_curr[:-1].x, df_curr[:-1].res, s=20, c='g', label='Train set ' + str(i))

    #for j in range(5):    
    #    plt.scatter(df_curr[-1:].x, df_curr[-1:].res, s=50+5**j, c='green', alpha=0.52-0.12*j, label='_')
    #    plt.scatter(df_curr[-1:].x, df_curr[-1:].predict,  s=50+5**j, c='red', alpha=0.52-0.12*j, label='_')
    #    plt.scatter(df_curr[-1:].x, df_curr[-1:].predict_ridge,  s=50+5**j, c='darkblue', alpha=0.52-0.12*j, label='_')

    #plt.plot(df_curr.x, df_curr.predict, '-', c='r', lw=0.8, ms=5, label='LinReg')
    #plt.plot(df_curr.x, df_curr.predict_ridge, '-', c='darkblue', lw=0.8, ms=5, label='LinReg Ridge')
    #plt.legend(loc='upper left', frameon=True)    
    
#print(len(df.index), len(preds))
print('First 10 predictions:', preds[:10])
print('LR time %.2f sec' % (time.time() - st))
print('Estimated time for full test data: %.2f min' % ((time.time() - st) * int(len(df.index)) / (60 * int(len(preds)))))
# Out:
# Sequences: 1000 of 113845 (0.88% done), time elapsed: 0.38 min, estimated time: 43.39 min
# Sequences: 2000 of 113845 (1.76% done), time elapsed: 0.76 min, estimated time: 43.35 min
# Sequences: 3000 of 113845 (2.64% done), time elapsed: 1.13 min, estimated time: 42.93 min
# Sequences: 4000 of 113845 (3.51% done), time elapsed: 1.46 min, estimated time: 41.57 min
# Sequences: 5000 of 113845 (4.39% done), time elapsed: 1.79 min, estimated time: 40.86 min
# Sequences: 6000 of 113845 (5.27% done), time elapsed: 2.13 min, estimated time: 40.45 min
# Sequences: 7000 of 113845 (6.15% done), time elapsed: 2.45 min, estimated time: 39.91 min
# Sequences: 8000 of 113845 (7.03% done), time elapsed: 2.79 min, estimated time: 39.63 min
# Sequences: 9000 of 113845 (7.91% done), time elapsed: 3.12 min, estimated time: 39.42 min
# Sequences: 10000 of 113845 (8.78% done), time elapsed: 3.45 min, estimated time: 39.31 min
# Sequences: 11000 of 113845 (9.66% done), time elapsed: 3.82 min, estimated time: 39.49 min
# Sequences: 12000 of 113845 (10.54% done), time elapsed: 4.26 min, estimated time: 40.37 min
# Sequences: 13000 of 113845 (11.42% done), time elapsed: 4.65 min, estimated time: 40.68 min
# Sequences: 14000 of 113845 (12.30% done), time elapsed: 5.16 min, estimated time: 41.92 min
# Sequences: 15000 of 113845 (13.18% done), time elapsed: 5.49 min, estimated time: 41.66 min
# Sequences: 16000 of 113845 (14.05% done), time elapsed: 5.97 min, estimated time: 42.45 min
# Sequences: 17000 of 113845 (14.93% done), time elapsed: 6.35 min, estimated time: 42.50 min
# Sequences: 18000 of 113845 (15.81% done), time elapsed: 6.69 min, estimated time: 42.34 min
# Sequences: 19000 of 113845 (16.69% done), time elapsed: 7.06 min, estimated time: 42.33 min
# Sequences: 20000 of 113845 (17.57% done), time elapsed: 7.41 min, estimated time: 42.19 min
# Sequences: 21000 of 113845 (18.45% done), time elapsed: 7.77 min, estimated time: 42.13 min
# Sequences: 22000 of 113845 (19.32% done), time elapsed: 8.15 min, estimated time: 42.20 min
# Sequences: 23000 of 113845 (20.20% done), time elapsed: 8.54 min, estimated time: 42.28 min
# Sequences: 24000 of 113845 (21.08% done), time elapsed: 8.96 min, estimated time: 42.51 min
# Sequences: 25000 of 113845 (21.96% done), time elapsed: 9.29 min, estimated time: 42.31 min
# Sequences: 26000 of 113845 (22.84% done), time elapsed: 9.63 min, estimated time: 42.19 min
# Sequences: 27000 of 113845 (23.72% done), time elapsed: 9.99 min, estimated time: 42.11 min
# Sequences: 28000 of 113845 (24.59% done), time elapsed: 10.34 min, estimated time: 42.03 min
# Sequences: 29000 of 113845 (25.47% done), time elapsed: 10.85 min, estimated time: 42.59 min
# Sequences: 30000 of 113845 (26.35% done), time elapsed: 11.35 min, estimated time: 43.06 min
# Sequences: 31000 of 113845 (27.23% done), time elapsed: 11.78 min, estimated time: 43.26 min
# Sequences: 32000 of 113845 (28.11% done), time elapsed: 12.26 min, estimated time: 43.62 min
# Sequences: 33000 of 113845 (28.99% done), time elapsed: 12.61 min, estimated time: 43.49 min
# Sequences: 34000 of 113845 (29.87% done), time elapsed: 12.98 min, estimated time: 43.48 min
# Sequences: 35000 of 113845 (30.74% done), time elapsed: 13.42 min, estimated time: 43.66 min
# Sequences: 36000 of 113845 (31.62% done), time elapsed: 13.78 min, estimated time: 43.57 min
# Sequences: 37000 of 113845 (32.50% done), time elapsed: 14.24 min, estimated time: 43.82 min
# Sequences: 38000 of 113845 (33.38% done), time elapsed: 14.61 min, estimated time: 43.76 min
# Sequences: 39000 of 113845 (34.26% done), time elapsed: 15.06 min, estimated time: 43.95 min
# Sequences: 40000 of 113845 (35.14% done), time elapsed: 15.43 min, estimated time: 43.91 min
# Sequences: 41000 of 113845 (36.01% done), time elapsed: 15.84 min, estimated time: 43.98 min
# Sequences: 42000 of 113845 (36.89% done), time elapsed: 16.33 min, estimated time: 44.25 min
# Sequences: 43000 of 113845 (37.77% done), time elapsed: 16.69 min, estimated time: 44.18 min
# Sequences: 44000 of 113845 (38.65% done), time elapsed: 17.05 min, estimated time: 44.12 min
# Sequences: 45000 of 113845 (39.53% done), time elapsed: 17.51 min, estimated time: 44.30 min
# Sequences: 46000 of 113845 (40.41% done), time elapsed: 17.88 min, estimated time: 44.26 min
# Sequences: 47000 of 113845 (41.28% done), time elapsed: 18.25 min, estimated time: 44.19 min
# Sequences: 48000 of 113845 (42.16% done), time elapsed: 18.64 min, estimated time: 44.22 min
# Sequences: 49000 of 113845 (43.04% done), time elapsed: 19.10 min, estimated time: 44.39 min
# Sequences: 50000 of 113845 (43.92% done), time elapsed: 19.53 min, estimated time: 44.47 min
# Sequences: 51000 of 113845 (44.80% done), time elapsed: 19.91 min, estimated time: 44.44 min
# Sequences: 52000 of 113845 (45.68% done), time elapsed: 20.30 min, estimated time: 44.44 min
# Sequences: 53000 of 113845 (46.55% done), time elapsed: 20.65 min, estimated time: 44.37 min
# Sequences: 54000 of 113845 (47.43% done), time elapsed: 21.01 min, estimated time: 44.30 min
# Sequences: 55000 of 113845 (48.31% done), time elapsed: 21.36 min, estimated time: 44.22 min
# Sequences: 56000 of 113845 (49.19% done), time elapsed: 21.73 min, estimated time: 44.18 min
# Sequences: 57000 of 113845 (50.07% done), time elapsed: 22.09 min, estimated time: 44.12 min
# Sequences: 58000 of 113845 (50.95% done), time elapsed: 22.46 min, estimated time: 44.09 min
# Sequences: 59000 of 113845 (51.82% done), time elapsed: 22.83 min, estimated time: 44.06 min
# Sequences: 60000 of 113845 (52.70% done), time elapsed: 23.18 min, estimated time: 43.97 min
# Sequences: 61000 of 113845 (53.58% done), time elapsed: 23.52 min, estimated time: 43.89 min
# Sequences: 62000 of 113845 (54.46% done), time elapsed: 23.86 min, estimated time: 43.82 min
# Sequences: 63000 of 113845 (55.34% done), time elapsed: 24.24 min, estimated time: 43.80 min
# Sequences: 64000 of 113845 (56.22% done), time elapsed: 24.60 min, estimated time: 43.76 min
# Sequences: 65000 of 113845 (57.10% done), time elapsed: 24.96 min, estimated time: 43.72 min
# Sequences: 66000 of 113845 (57.97% done), time elapsed: 25.52 min, estimated time: 44.02 min
# Sequences: 67000 of 113845 (58.85% done), time elapsed: 26.15 min, estimated time: 44.44 min
# Sequences: 68000 of 113845 (59.73% done), time elapsed: 26.66 min, estimated time: 44.63 min
# Sequences: 69000 of 113845 (60.61% done), time elapsed: 27.09 min, estimated time: 44.69 min
# Sequences: 70000 of 113845 (61.49% done), time elapsed: 27.52 min, estimated time: 44.76 min
# Sequences: 71000 of 113845 (62.37% done), time elapsed: 27.91 min, estimated time: 44.75 min
# Sequences: 72000 of 113845 (63.24% done), time elapsed: 28.27 min, estimated time: 44.70 min
# Sequences: 73000 of 113845 (64.12% done), time elapsed: 28.81 min, estimated time: 44.93 min
# Sequences: 74000 of 113845 (65.00% done), time elapsed: 29.24 min, estimated time: 44.98 min
# Sequences: 75000 of 113845 (65.88% done), time elapsed: 29.67 min, estimated time: 45.04 min
# Sequences: 76000 of 113845 (66.76% done), time elapsed: 30.04 min, estimated time: 45.00 min
# Sequences: 77000 of 113845 (67.64% done), time elapsed: 30.42 min, estimated time: 44.98 min
# Sequences: 78000 of 113845 (68.51% done), time elapsed: 30.77 min, estimated time: 44.91 min
# Sequences: 79000 of 113845 (69.39% done), time elapsed: 31.10 min, estimated time: 44.82 min
# Sequences: 80000 of 113845 (70.27% done), time elapsed: 31.43 min, estimated time: 44.73 min
# Sequences: 81000 of 113845 (71.15% done), time elapsed: 31.77 min, estimated time: 44.65 min
# Sequences: 82000 of 113845 (72.03% done), time elapsed: 32.12 min, estimated time: 44.59 min
# Sequences: 83000 of 113845 (72.91% done), time elapsed: 32.47 min, estimated time: 44.54 min
# Sequences: 84000 of 113845 (73.78% done), time elapsed: 32.87 min, estimated time: 44.55 min
# Sequences: 85000 of 113845 (74.66% done), time elapsed: 33.21 min, estimated time: 44.48 min
# Sequences: 86000 of 113845 (75.54% done), time elapsed: 33.55 min, estimated time: 44.42 min
# Sequences: 87000 of 113845 (76.42% done), time elapsed: 33.95 min, estimated time: 44.43 min
# Sequences: 88000 of 113845 (77.30% done), time elapsed: 34.37 min, estimated time: 44.46 min
# Sequences: 89000 of 113845 (78.18% done), time elapsed: 34.71 min, estimated time: 44.40 min
# Sequences: 90000 of 113845 (79.05% done), time elapsed: 35.05 min, estimated time: 44.33 min
# Sequences: 91000 of 113845 (79.93% done), time elapsed: 35.40 min, estimated time: 44.29 min
# Sequences: 92000 of 113845 (80.81% done), time elapsed: 35.76 min, estimated time: 44.25 min
# Sequences: 93000 of 113845 (81.69% done), time elapsed: 36.10 min, estimated time: 44.19 min
# Sequences: 94000 of 113845 (82.57% done), time elapsed: 36.45 min, estimated time: 44.14 min
# Sequences: 95000 of 113845 (83.45% done), time elapsed: 36.90 min, estimated time: 44.22 min
# Sequences: 96000 of 113845 (84.33% done), time elapsed: 37.32 min, estimated time: 44.26 min
# Sequences: 97000 of 113845 (85.20% done), time elapsed: 37.74 min, estimated time: 44.29 min
# Sequences: 98000 of 113845 (86.08% done), time elapsed: 38.16 min, estimated time: 44.33 min
# Sequences: 99000 of 113845 (86.96% done), time elapsed: 38.51 min, estimated time: 44.28 min
# Sequences: 100000 of 113845 (87.84% done), time elapsed: 38.98 min, estimated time: 44.38 min
# Sequences: 101000 of 113845 (88.72% done), time elapsed: 39.35 min, estimated time: 44.35 min
# Sequences: 102000 of 113845 (89.60% done), time elapsed: 39.70 min, estimated time: 44.31 min
# Sequences: 103000 of 113845 (90.47% done), time elapsed: 40.14 min, estimated time: 44.36 min
# Sequences: 104000 of 113845 (91.35% done), time elapsed: 40.53 min, estimated time: 44.37 min
# Sequences: 105000 of 113845 (92.23% done), time elapsed: 40.89 min, estimated time: 44.33 min
# Sequences: 106000 of 113845 (93.11% done), time elapsed: 41.26 min, estimated time: 44.31 min
# Sequences: 107000 of 113845 (93.99% done), time elapsed: 41.61 min, estimated time: 44.28 min
# Sequences: 108000 of 113845 (94.87% done), time elapsed: 41.98 min, estimated time: 44.25 min
# Sequences: 109000 of 113845 (95.74% done), time elapsed: 42.35 min, estimated time: 44.23 min
# Sequences: 110000 of 113845 (96.62% done), time elapsed: 42.71 min, estimated time: 44.20 min
# Sequences: 111000 of 113845 (97.50% done), time elapsed: 43.11 min, estimated time: 44.21 min
# Sequences: 112000 of 113845 (98.38% done), time elapsed: 43.53 min, estimated time: 44.25 min
# Sequences: 113000 of 113845 (99.26% done), time elapsed: 43.92 min, estimated time: 44.24 min
# First 10 predictions: [0, 725161963867.0, 158, 406, 24, 1430, 1, 0, 10576607847561078339796992, 2795903786354347606016]
# LR time 2651.27 sec
# Estimated time for full test data: 44.19 min

# %%
df.loc[:len(preds) - 1, 'preds'] = preds
df['Last'] = df.recursion
df.preds.fillna(df.ints_list.apply(lambda x: x[-1]), inplace=True)
df.Last.fillna(df.preds, inplace=True)
df['Last'] = df['Last'].apply(lambda x: int(np.round(float(x))) if x != np.inf else 1)
print(df[['Id', 'Last']].head(10))
df[['Id', 'Last']].to_csv('submission.csv', sep=',', index=False)
# Out:
#    Id                        Last
# 0   1                           0
# 1   2                725161963867
# 2   4                         158
# 3   5                         406
# 4   6                          24
# 5   9                        1430
# 6  10                           1
# 7  12                           0
# 8  14  10576607847561078339796992
# 9  17      2795903786354347606016
